# %% [markdown]
# ### In this notebook, I will explore the area where a local Dessert Shop is located.  The business wants to place advertisement boards in areas that have the most Dining activity, so we want to find the areas with highest density of Restaurant type businesses.  Since the Ad Boards are supposed to drive traffic to the Dessert Shop, it is best to place them within a couple of kilometers distance.  I will use Foursquare data for the local restaurant venues, then map with Folium for visualization, analyze the distribution with Kmeans clustering, and make the recommendation.

# %%
# First I need to load some resources
import requests # library to handle requests
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import numpy as np # library to handle data in a vectorized manner

# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

import json # library to handle JSON files


from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

from sklearn.preprocessing import StandardScaler

! pip install folium==0.5.0 # Install Folium
import folium # map rendering library

print('Libraries imported.')
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting folium==0.5.0
#   Downloading folium-0.5.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 8.6 MB/s  eta 0:00:01
# Collecting branca
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.11.3)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2021.5.30)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76240 sha256=8c41ea906b94f8e10405567b56fcf90132f2376738ff9c8b7847319a7468d3e8
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/b2/2f/2c/109e446b990d663ea5ce9b078b5e7c1a9c45cca91f377080f8
# Successfully built folium
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.5.0
# Libraries imported.

# %%
# The code was removed by Watson Studio for sharing.

# %%
#Assign values to my variables for Foursquare, including the known coordinates of the Client's location
VERSION = '20180605'
latitude = 33.951113
longitude= -84.142667
RADIUS = 1500
LIMIT = 1000

# %%
# create the request URI and perform the Get from Foursquare API

uri = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&query=food&ll={},{}&radius={}&limit={}'.format(
      CLIENT_ID, 
      CLIENT_SECRET, 
      VERSION, 
      latitude, 
      longitude, 
      RADIUS, 
      LIMIT)
# make the GET request
results = requests.get(uri).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60d323257416412c48ac2aa1'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'query': 'food',
#   'totalResults': 96,
#   'suggestedBounds': {'ne': {'lat': 33.96461301350001,
#     'lng': -84.12642278833181},
#    'sw': {'lat': 33.937612986499985, 'lng': -84.1589112116682}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f25a2a1e4b0020c30029121',
#        'name': 'Costco Food Court',
#        'location': {'lat': 33.94741597245879,
#         'lng': -84.14296297895811,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.94741597245879,
#           'lng': -84.14296297895811}],
#         'distance': 412,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['Duluth, GA 30096', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f25a2a1e4b0020c30029121-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b65ef10f964a52055092be3',
#        'name': 'Jang Su Jang',
#        'location': {'address': '3645 Satellite Blvd',
#         'lat': 33.95704005333993,
#         'lng': -84.13876309732005,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.95704005333993,
#           'lng': -84.13876309732005},
#          {'label': 'entrance', 'lat': 33.957108, 'lng': -84.138799}],
#         'distance': 751,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3645 Satellite Blvd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1467813',
#         'url': 'https://www.grubhub.com/restaurant/jang-su-jang-3645-satellite-blvd-duluth/1467813?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1467813',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b65ef10f964a52055092be3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a3bca6af964a520c4a01fe3',
#        'name': 'Haru Ichiban',
#        'location': {'address': '3646 Satellite Blvd',
#         'lat': 33.95689315794606,
#         'lng': -84.13639922413105,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.95689315794606,
#           'lng': -84.13639922413105}],
#         'distance': 865,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3646 Satellite Blvd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2037605',
#         'url': 'https://www.grubhub.com/restaurant/haru-ichiban-3646-satellite-blvd-duluth/2037605?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2037605',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a3bca6af964a520c4a01fe3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f32a5fb19836c91c7ec3a69',
#        'name': 'Paris Baguette',
#        'location': {'address': '3365 Steve Reynolds Blvd',
#         'lat': 33.95294952392578,
#         'lng': -84.14099884033203,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.95294952392578,
#           'lng': -84.14099884033203}],
#         'distance': 255,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3365 Steve Reynolds Blvd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f32a5fb19836c91c7ec3a69-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fdbd032e4b09d541722a07d',
#        'name': '678 (육칠팔)',
#        'location': {'address': '3880 Satellite Blvd',
#         'lat': 33.953473388614725,
#         'lng': -84.14215327146748,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.953473388614725,
#           'lng': -84.14215327146748}],
#         'distance': 267,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3880 Satellite Blvd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fdbd032e4b09d541722a07d-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1e97eaf964a520391c24e3',
#        'name': 'El Torero',
#        'location': {'address': '3656 Satellite Blvd',
#         'lat': 33.95689438153436,
#         'lng': -84.1367528329026,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.95689438153436,
#           'lng': -84.1367528329026}],
#         'distance': 844,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3656 Satellite Blvd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1468374',
#         'url': 'https://www.grubhub.com/restaurant/el-torero-mexican-restaurant-3656-satellite-boulevard-duluth/1468374?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1468374',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1e97eaf964a520391c24e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55abb4ff498e0ce438ee7554',
#        'name': 'Sweet Hut Bakery & Cafe',
#        'location': {'address': '2180 Pleasant Hill Rd Ste 18',
#         'lat': 33.962225043522785,
#         'lng': -84.13522807556453,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.962225043522785,
#           'lng': -84.13522807556453}],
#         'distance': 1414,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['2180 Pleasant Hill Rd Ste 18',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2592223',
#         'url': 'https://www.grubhub.com/restaurant/sweet-hut-bakery--cafe-2180-pleasant-hill-rd-duluth/2592223?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2592223',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '141979383'}},
#       'referralId': 'e-0-55abb4ff498e0ce438ee7554-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b2d1a43f964a52056ce24e3',
#        'name': 'Saigon Cafe Duluth',
#        'location': {'address': '3675 Satellite Blvd #750',
#         'crossStreet': 'and Pleasant Hill Rd',
#         'lat': 33.96012236013812,
#         'lng': -84.13615842313993,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.96012236013812,
#           'lng': -84.13615842313993}],
#         'distance': 1169,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3675 Satellite Blvd #750 (and Pleasant Hill Rd)',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1239295',
#         'url': 'https://www.grubhub.com/restaurant/saigon-cafe-3675-satellite-blvd-ste-750-duluth/1239295?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1239295',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b2d1a43f964a52056ce24e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc11508920eb7137e361a2c',
#        'name': 'Iron Age',
#        'location': {'address': '2131 Pleasant Hill Rd Ste B4',
#         'crossStreet': 'Mall Corners',
#         'lat': 33.95417469742934,
#         'lng': -84.13357853002559,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.95417469742934,
#           'lng': -84.13357853002559}],
#         'distance': 905,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['2131 Pleasant Hill Rd Ste B4 (Mall Corners)',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc11508920eb7137e361a2c-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc8a5066501c9b6bf934029',
#        'name': 'Georgia French Bakery and Cafe',
#        'location': {'address': '3512 Satellite Blvd',
#         'crossStreet': 'Merchants Way',
#         'lat': 33.960856436157485,
#         'lng': -84.13243096115153,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.960856436157485,
#           'lng': -84.13243096115153},
#          {'label': 'entrance', 'lat': 33.960716, 'lng': -84.132219}],
#         'distance': 1438,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3512 Satellite Blvd (Merchants Way)',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2484412',
#         'url': 'https://www.grubhub.com/restaurant/georgia-french-bakery-3512-satellite-blvd-duluth/2484412?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2484412',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc8a5066501c9b6bf934029-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3bfcfef964a520de7f25e3',
#        'name': 'The Melting Pot',
#        'location': {'address': '3610 Satellite Boulevard Northwest Mall Corners Shopping Center',
#         'lat': 33.957199,
#         'lng': -84.135215,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.957199,
#           'lng': -84.135215}],
#         'distance': 965,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3610 Satellite Boulevard Northwest Mall Corners Shopping Center',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a09',
#          'name': 'Fondue Restaurant',
#          'pluralName': 'Fondue Restaurants',
#          'shortName': 'Fondue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b3bfcfef964a520de7f25e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf1cb6278cec9282bd5ba86',
#        'name': 'Ching Mei',
#        'location': {'address': '3230 Steve Reynolds Blvd',
#         'lat': 33.958221516302224,
#         'lng': -84.14015039502773,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.958221516302224,
#           'lng': -84.14015039502773}],
#         'distance': 824,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3230 Steve Reynolds Blvd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1468175',
#         'url': 'https://www.grubhub.com/restaurant/ching-mei-3230-steve-reynolds-boulevard-duluth/1468175?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1468175',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf1cb6278cec9282bd5ba86-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5441acca498ef447ef6b4661',
#        'name': 'kabob-ish',
#        'location': {'lat': 33.95660644442316,
#         'lng': -84.13090189866014,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.95660644442316,
#           'lng': -84.13090189866014}],
#         'distance': 1246,
#         'cc': 'US',
#         'state': 'Georgia',
#         'country': 'United States',
#         'formattedAddress': ['Georgia', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1153068',
#         'url': 'https://www.grubhub.com/restaurant/kabob-ish-3555-gwinnett-place-dr-ste-105-duluth/1153068?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1153068',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5441acca498ef447ef6b4661-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57ef1430498e1c397a6707b0',
#        'name': 'VeGreen',
#        'location': {'address': '3780 Old Norcross Rd Ste 106',
#         'lat': 33.96122905419354,
#         'lng': -84.14373135082246,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.96122905419354,
#           'lng': -84.14373135082246}],
#         'distance': 1130,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3780 Old Norcross Rd Ste 106',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57ef1430498e1c397a6707b0-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54c97da4498ec69b44a34f56',
#        'name': 'Krispy Kreme Doughnuts',
#        'location': {'address': '2346 Pleasant Hill Rd',
#         'lat': 33.964059,
#         'lng': -84.138726,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.964059,
#           'lng': -84.138726},
#          {'label': 'entrance', 'lat': 33.963964, 'lng': -84.138803}],
#         'distance': 1486,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['2346 Pleasant Hill Rd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d148941735',
#          'name': 'Donut Shop',
#          'pluralName': 'Donut Shops',
#          'shortName': 'Donuts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54c97da4498ec69b44a34f56-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bec45c1b68520a1dedf1187',
#        'name': 'Little Caesars Pizza',
#        'location': {'address': '3780 Old Norcross Rd',
#         'lat': 33.96003897151617,
#         'lng': -84.14270595001175,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.96003897151617,
#           'lng': -84.14270595001175}],
#         'distance': 993,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3780 Old Norcross Rd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bec45c1b68520a1dedf1187-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5ed782f964a5209c9a29e3',
#        'name': 'la Madeleine Country French Café',
#        'location': {'address': '2255 Pleasant Hill Rd #480',
#         'crossStreet': 'Old Norcross Rd',
#         'lat': 33.96187359353677,
#         'lng': -84.13892213255961,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.96187359353677,
#           'lng': -84.13892213255961}],
#         'distance': 1246,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['2255 Pleasant Hill Rd #480 (Old Norcross Rd)',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1739754',
#         'url': 'https://www.grubhub.com/restaurant/la-madeleine-2255-pleasant-hill-rd-ste-480-duluth/1739754?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1739754',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5ed782f964a5209c9a29e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50c8d058e4b027054284e571',
#        'name': 'Banh Mi Café',
#        'location': {'address': '3512 Satellite Blvd',
#         'lat': 33.960618410382935,
#         'lng': -84.13234547366227,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.960618410382935,
#           'lng': -84.13234547366227}],
#         'distance': 1424,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3512 Satellite Blvd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1467630',
#         'url': 'https://www.grubhub.com/restaurant/banh-mi-cafe-3512-satellite-boulevard-duluth/1467630?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1467630',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '149555529'}},
#       'referralId': 'e-0-50c8d058e4b027054284e571-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5e4548f964a520fe8629e3',
#        'name': 'Mini Hot Pot 2',
#        'location': {'address': '2174 Pleasant Hill Rd Ste 101',
#         'lat': 33.959821571157214,
#         'lng': -84.13484781206954,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.959821571157214,
#           'lng': -84.13484781206954}],
#         'distance': 1208,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['2174 Pleasant Hill Rd Ste 101',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1328462',
#         'url': 'https://www.grubhub.com/restaurant/89-hot-pot-2180-pleasant-hill-road-duluth/1328462?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1328462',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5e4548f964a520fe8629e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '563ac6c6498eaf512a5a8ffc',
#        'name': 'The Juicy Crab',
#        'location': {'address': '2205 Pleasant Hill Rd Ste 130',
#         'lat': 33.960534,
#         'lng': -84.1371649,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.960534,
#           'lng': -84.1371649}],
#         'distance': 1165,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['2205 Pleasant Hill Rd Ste 130',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1468156',
#         'url': 'https://www.grubhub.com/restaurant/the-juicy-crab-2205-pleasant-hill-road-duluth/1468156?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1468156',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-563ac6c6498eaf512a5a8ffc-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b206f66f964a5203d3224e3',
#        'name': 'Bahama Breeze',
#        'location': {'address': '3590 Breckinridge Blvd',
#         'lat': 33.949249820538725,
#         'lng': -84.12716672201357,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.949249820538725,
#           'lng': -84.12716672201357}],
#         'distance': 1446,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3590 Breckinridge Blvd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'shortName': 'Caribbean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b206f66f964a5203d3224e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b21127bf964a520983624e3',
#        'name': 'Subway',
#        'location': {'address': '3662 Satellite Blvd',
#         'lat': 33.956984,
#         'lng': -84.1369775,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.956984,
#           'lng': -84.1369775}],
#         'distance': 838,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3662 Satellite Blvd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2722368',
#         'url': 'https://www.grubhub.com/restaurant/subway-3662-satellite-boulevard-duluth/2722368?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2722368',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b21127bf964a520983624e3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f807c86e4b0ef2098305d47',
#        'name': 'A-Hyang',
#        'location': {'address': '3230 Steve Reynolds Blvd, Duluth, GA 30096',
#         'lat': 33.95775780496929,
#         'lng': -84.14117270276799,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.95775780496929,
#           'lng': -84.14117270276799},
#          {'label': 'entrance', 'lat': 33.957847, 'lng': -84.141382}],
#         'distance': 752,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3230 Steve Reynolds Blvd, Duluth, GA 30096',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f807c86e4b0ef2098305d47-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5064cbf964a520152227e3',
#        'name': 'Einstein Bros Bagels',
#        'location': {'address': '3675 Satellite Blvd',
#         'lat': 33.9601291,
#         'lng': -84.1359535,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.9601291,
#           'lng': -84.1359535}],
#         'distance': 1179,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3675 Satellite Blvd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d179941735',
#          'name': 'Bagel Shop',
#          'pluralName': 'Bagel Shops',
#          'shortName': 'Bagels',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5064cbf964a520152227e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdb0d57c79cc92884e080e9',
#        'name': 'Roly Poly',
#        'location': {'address': '3675 Satellite Blvd',
#         'crossStreet': 'at Pleasant Hill Rd',
#         'lat': 33.95961947677541,
#         'lng': -84.135751432892,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.95961947677541,
#           'lng': -84.135751432892}],
#         'distance': 1142,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3675 Satellite Blvd (at Pleasant Hill Rd)',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '996892',
#         'url': 'https://www.grubhub.com/restaurant/roly-poly-sandwiches-3675-satellite-blvd-ste-1000-duluth/996892?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=996892',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdb0d57c79cc92884e080e9-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6b7e3af964a5204c0c2ce3',
#        'name': 'Checkers',
#        'location': {'address': '2336 Pleasant Hill Rd',
#         'lat': 33.96349621865536,
#         'lng': -84.13810651114659,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.96349621865536,
#           'lng': -84.13810651114659},
#          {'label': 'entrance', 'lat': 33.963447, 'lng': -84.138153}],
#         'distance': 1441,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['2336 Pleasant Hill Rd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2556545',
#         'url': 'https://www.grubhub.com/restaurant/checkers-2336-pleasant-hill-rd-duluth/2556545?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2556545',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6b7e3af964a5204c0c2ce3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5664b0be498e7d1d0e5762c5',
#        'name': "Dunkin'",
#        'location': {'address': '2001 Pleasant Hill Rd',
#         'lat': 33.954609762869175,
#         'lng': -84.13237218925485,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.954609762869175,
#           'lng': -84.13237218925485}],
#         'distance': 1027,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['2001 Pleasant Hill Rd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d148941735',
#          'name': 'Donut Shop',
#          'pluralName': 'Donut Shops',
#          'shortName': 'Donuts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2051066',
#         'url': 'https://www.grubhub.com/restaurant/dunkin-2001-pleasant-hill-rd-duluth/2051066?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2051066',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5664b0be498e7d1d0e5762c5-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af8bac4f964a5208c0f22e3',
#        'name': 'Red Lobster',
#        'location': {'address': '2055 Pleasant Hill Road',
#         'crossStreet': 'at Venture Blvd',
#         'lat': 33.955604,
#         'lng': -84.13297,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.955604,
#           'lng': -84.13297}],
#         'distance': 1025,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['2055 Pleasant Hill Road (at Venture Blvd)',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '625423',
#         'url': 'https://www.grubhub.com/restaurant/red-lobster-2055-pleasant-hill-rd-duluth/625423?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=625423',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af8bac4f964a5208c0f22e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0d94d2b1b676b062dde086',
#        'name': 'Dan Moo Ji',
#        'location': {'address': '3230 Steve Reynolds Blvd',
#         'lat': 33.95785361845068,
#         'lng': -84.14097271584524,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.95785361845068,
#           'lng': -84.14097271584524}],
#         'distance': 766,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3230 Steve Reynolds Blvd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2116485',
#         'url': 'https://www.grubhub.com/restaurant/dan-moo-ji-3230-steve-reynolds-blvd-107-duluth/2116485?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2116485',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0d94d2b1b676b062dde086-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bce7684b6c49c7410529791',
#        'name': 'Seo Ra Beol Restaurant',
#        'location': {'address': '3040 Steve Reynolds Blvd',
#         'crossStreet': 'at Old Norcross Rd',
#         'lat': 33.963875612891165,
#         'lng': -84.14196439914087,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.963875612891165,
#           'lng': -84.14196439914087},
#          {'label': 'entrance', 'lat': 33.964151, 'lng': -84.14222}],
#         'distance': 1422,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3040 Steve Reynolds Blvd (at Old Norcross Rd)',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2649174',
#         'url': 'https://www.grubhub.com/restaurant/seo-ra-beol-3040-steve-reynolds-blvd-duluth/2649174?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2649174',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bce7684b6c49c7410529791-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc8883214d79521493569e9',
#        'name': 'Gom Shabu Shabu',
#        'location': {'address': '3502 Satellite Blvd',
#         'lat': 33.96135504209736,
#         'lng': -84.13225096332843,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.96135504209736,
#           'lng': -84.13225096332843},
#          {'label': 'entrance', 'lat': 33.961256, 'lng': -84.13207}],
#         'distance': 1491,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3502 Satellite Blvd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc8883214d79521493569e9-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54bd8c82498e4279526f1494',
#        'name': "Breaker's Korean Bar-B-Q",
#        'location': {'address': '3505 Gwinnett Place Dr #101',
#         'lat': 33.9575294,
#         'lng': -84.12875389999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.9575294,
#           'lng': -84.12875389999999}],
#         'distance': 1469,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3505 Gwinnett Place Dr #101',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2193063',
# ...
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9bdee1f964a5209c2f36e3-84'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57bb838e498e805393c83518',
#        'name': 'Bo Bo Garden 2 Asian Cuisine',
#        'location': {'address': '3780 Old Norcross Road, Ste 113',
#         'lat': 33.961243,
#         'lng': -84.14453,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.961243,
#           'lng': -84.14453}],
#         'distance': 1140,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3780 Old Norcross Road, Ste 113',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57bb838e498e805393c83518-85'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b60ddf8f964a52099fe29e3',
#        'name': 'Sun & Moon Cafe',
#        'location': {'address': '3555 Gwinnett Place Dr #101',
#         'lat': 33.95642986739736,
#         'lng': -84.13144270562286,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.95642986739736,
#           'lng': -84.13144270562286},
#          {'label': 'entrance', 'lat': 33.956491, 'lng': -84.131092}],
#         'distance': 1193,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3555 Gwinnett Place Dr #101',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1467348',
#         'url': 'https://www.grubhub.com/restaurant/sun-and-moon-cafe-3555-gwinnett-place-drive-northwest-duluth/1467348?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1467348',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b60ddf8f964a52099fe29e3-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '582906413398744fe410949e',
#        'name': 'Pop Pot 个人食膳锅',
#        'location': {'address': '2180 Pleasant Hill Rd Ste B1',
#         'lat': 33.96080949509628,
#         'lng': -84.13445788733956,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.96080949509628,
#           'lng': -84.13445788733956}],
#         'distance': 1318,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['2180 Pleasant Hill Rd Ste B1',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1468234',
#         'url': 'https://www.grubhub.com/restaurant/pop-pot-2180-pleasant-hill-road-duluth/1468234?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1468234',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-582906413398744fe410949e-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55f755fa498e079406ebc086',
#        'name': 'North Dumpling House',
#        'location': {'address': '2180 Pleasant Hill Rd Ste B5',
#         'lat': 33.960799090645644,
#         'lng': -84.1340471991837,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.960799090645644,
#           'lng': -84.1340471991837}],
#         'distance': 1340,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['2180 Pleasant Hill Rd Ste B5',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d108941735',
#          'name': 'Dumpling Restaurant',
#          'pluralName': 'Dumpling Restaurants',
#          'shortName': 'Dumplings',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dumplings_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1330893',
#         'url': 'https://www.grubhub.com/restaurant/north-dumpling-2180-pleasant-hill-road-duluth/1330893?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1330893',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55f755fa498e079406ebc086-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5897657cfc73d40bedcdb576',
#        'name': 'Boiled Skewer',
#        'location': {'address': '2180 Pleasant Hill Rd Ste B3',
#         'lat': 33.960873,
#         'lng': -84.13407,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.960873,
#           'lng': -84.13407}],
#         'distance': 1345,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['2180 Pleasant Hill Rd Ste B3',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2285328',
#         'url': 'https://www.grubhub.com/restaurant/boiled-skewer-2180-pleasant-hill-rd-duluth/2285328?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2285328',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5897657cfc73d40bedcdb576-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '548cfc12498e280856d89851',
#        'name': 'Cafe Chocolat',
#        'location': {'lat': 33.96329084109723,
#         'lng': -84.14225887741853,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.96329084109723,
#           'lng': -84.14225887741853},
#          {'label': 'entrance', 'lat': 33.963288, 'lng': -84.141787}],
#         'distance': 1356,
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['Duluth, GA', 'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a09',
#          'name': 'Fondue Restaurant',
#          'pluralName': 'Fondue Restaurants',
#          'shortName': 'Fondue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2395569',
#         'url': 'https://www.grubhub.com/restaurant/cafe-chocolat-3725-old-norcross-road-duluth/2395569?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2395569',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-548cfc12498e280856d89851-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d1f903733b32000230980fb',
#        'name': 'BB.Q Chicken',
#        'location': {'address': '3530 Mall Blvd #B',
#         'lat': 33.95832443237305,
#         'lng': -84.13078308105469,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.95832443237305,
#           'lng': -84.13078308105469}],
#         'distance': 1359,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3530 Mall Blvd #B',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2353007',
#         'url': 'https://www.grubhub.com/restaurant/bbq-chicken-3530-mall-blvd-nw-ste-b-duluth/2353007?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2353007',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d1f903733b32000230980fb-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1611f7a5eb76b02e2bc4b7',
#        'name': 'Grapevine Restaurant',
#        'location': {'address': '1775 Pleasant Hill Rd',
#         'lat': 33.94793021453194,
#         'lng': -84.1280543117437,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.94793021453194,
#           'lng': -84.1280543117437}],
#         'distance': 1395,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['1775 Pleasant Hill Rd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1611f7a5eb76b02e2bc4b7-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57110f99498e20f5ea0c0863',
#        'name': 'Sichuan Garden',
#        'location': {'lat': 33.96185184727762,
#         'lng': -84.1348174511294,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.96185184727762,
#           'lng': -84.1348174511294}],
#         'distance': 1397,
#         'cc': 'US',
#         'state': 'Georgia',
#         'country': 'United States',
#         'formattedAddress': ['Georgia', 'United States']},
#        'categories': [{'id': '52af3b773cf9994f4e043c03',
#          'name': 'Szechuan Restaurant',
#          'pluralName': 'Szechuan Restaurants',
#          'shortName': 'Szechuan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57110f99498e20f5ea0c0863-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b51ecc3f964a5209c5b27e3',
#        'name': 'Kuk Poong',
#        'location': {'address': '3525 Mall Blvd',
#         'lat': 33.960123078066424,
#         'lng': -84.131060314552,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.960123078066424,
#           'lng': -84.131060314552}],
#         'distance': 1467,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3525 Mall Blvd',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b51ecc3f964a5209c5b27e3-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5186eac5498e1f88aa70079c',
#        'name': 'Chef Wong',
#        'location': {'address': '3525 Mall Blvd Ste 1A',
#         'lat': 33.960243,
#         'lng': -84.131183,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.960243,
#           'lng': -84.131183}],
#         'distance': 1468,
#         'postalCode': '30096',
#         'cc': 'US',
#         'city': 'Duluth',
#         'state': 'GA',
#         'country': 'United States',
#         'formattedAddress': ['3525 Mall Blvd Ste 1A',
#          'Duluth, GA 30096',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5186eac5498e1f88aa70079c-95'}]}]}}

# %% [markdown]
# #### So, we know all of these venues are restaurants.  Now, we can put them in a dataframe, and clean it, by removing the extra columns.

# %%
# assign relevant part of JSON to venues
venues = results['response']['groups'][0]['items']

# tranform venues into a dataframe
near_venues = json_normalize(venues)
near_venues.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                        referralId  reasons.count  \
# 0  e-0-4f25a2a1e4b0020c30029121-0              0
# 1  e-0-4b65ef10f964a52055092be3-1              0
# 2  e-0-4a3bca6af964a520c4a01fe3-2              0
# 3  e-0-4f32a5fb19836c91c7ec3a69-3              0
# 4  e-0-4fdbd032e4b09d541722a07d-4              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
# 3  [{'summary': 'This spot is popular', 'type': '...
# 4  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id         venue.name  venue.location.lat  \
# 0  4f25a2a1e4b0020c30029121  Costco Food Court           33.947416
# 1  4b65ef10f964a52055092be3       Jang Su Jang           33.957040
# 2  4a3bca6af964a520c4a01fe3       Haru Ichiban           33.956893
# 3  4f32a5fb19836c91c7ec3a69     Paris Baguette           33.952950
# 4  4fdbd032e4b09d541722a07d          678 (육칠팔)           33.953473
#
#    venue.location.lng                      venue.location.labeledLatLngs  \
# 0          -84.142963  [{'label': 'display', 'lat': 33.94741597245879...
# 1          -84.138763  [{'label': 'display', 'lat': 33.95704005333993...
# 2          -84.136399  [{'label': 'display', 'lat': 33.95689315794606...
# 3          -84.140999  [{'label': 'display', 'lat': 33.95294952392578...
# 4          -84.142153  [{'label': 'display', 'lat': 33.95347338861472...
#
#    venue.location.distance venue.location.postalCode venue.location.cc  \
# 0                      412                     30096                US
# 1                      751                     30096                US
# 2                      865                     30096                US
# 3                      255                     30096                US
# 4                      267                     30096                US
#
#   venue.location.city venue.location.state venue.location.country  \
# 0              Duluth                   GA          United States
# 1              Duluth                   GA          United States
# 2              Duluth                   GA          United States
# 3              Duluth                   GA          United States
# 4              Duluth                   GA          United States
#
#                      venue.location.formattedAddress  \
# 0                  [Duluth, GA 30096, United States]
# 1  [3645 Satellite Blvd, Duluth, GA 30096, United...
# 2  [3646 Satellite Blvd, Duluth, GA 30096, United...
# 3  [3365 Steve Reynolds Blvd, Duluth, GA 30096, U...
# 4  [3880 Satellite Blvd, Duluth, GA 30096, United...
#
#                                     venue.categories  venue.photos.count  \
# 0  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...                   0
# 1  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...                   0
# 2  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...                   0
# 3  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...                   0
# 4  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...                   0
#
#   venue.photos.groups    venue.location.address venue.delivery.id  \
# 0                  []                       NaN               NaN
# 1                  []       3645 Satellite Blvd           1467813
# 2                  []       3646 Satellite Blvd           2037605
# 3                  []  3365 Steve Reynolds Blvd               NaN
# 4                  []       3880 Satellite Blvd               NaN
#
#                                   venue.delivery.url  \
# 0                                                NaN
# 1  https://www.grubhub.com/restaurant/jang-su-jan...
# 2  https://www.grubhub.com/restaurant/haru-ichiba...
# 3                                                NaN
# 4                                                NaN
#
#   venue.delivery.provider.name       venue.delivery.provider.icon.prefix  \
# 0                          NaN                                       NaN
# 1                      grubhub  https://fastly.4sqi.net/img/general/cap/
# 2                      grubhub  https://fastly.4sqi.net/img/general/cap/
# 3                          NaN                                       NaN
# 4                          NaN                                       NaN
#
#   venue.delivery.provider.icon.sizes        venue.delivery.provider.icon.name  \
# 0                                NaN                                      NaN
# 1                           [40, 50]  /delivery_provider_grubhub_20180129.png
# 2                           [40, 50]  /delivery_provider_grubhub_20180129.png
# 3                                NaN                                      NaN
# 4                                NaN                                      NaN
#
#   venue.venuePage.id venue.location.crossStreet
# 0                NaN                        NaN
# 1                NaN                        NaN
# 2                NaN                        NaN
# 3                NaN                        NaN
# 4                NaN                        NaN

# %%
# Create a new dataframe, from the three relevant columns
ad_venues = near_venues[['venue.name', 'venue.location.lat', 'venue.location.lng']]
ad_venues.head()
# Out:
#           venue.name  venue.location.lat  venue.location.lng
# 0  Costco Food Court           33.947416          -84.142963
# 1       Jang Su Jang           33.957040          -84.138763
# 2       Haru Ichiban           33.956893          -84.136399
# 3     Paris Baguette           33.952950          -84.140999
# 4          678 (육칠팔)           33.953473          -84.142153

# %%
#Let's make sure we have all of the records
ad_venues.shape
# Out:
# (96, 3)

# %%
#Now, rename the columns
ad_venues.rename(columns = {"venue.name":"VenueName", "venue.location.lat":"Latitude", "venue.location.lng":"Longitude"}, inplace="True")
ad_venues.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#            VenueName   Latitude  Longitude
# 0  Costco Food Court  33.947416 -84.142963
# 1       Jang Su Jang  33.957040 -84.138763
# 2       Haru Ichiban  33.956893 -84.136399
# 3     Paris Baguette  33.952950 -84.140999
# 4          678 (육칠팔)  33.953473 -84.142153

# %%
# create map of the local area around the business, using known latitude and longitude values
map_local = folium.Map(location=[latitude, longitude], zoom_start=14)

# add a red circle marker to represent the Client's Shop
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Client Dessert Shop',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(map_local)


# add markers to map
for lat, lng, name in zip(ad_venues['Latitude'], ad_venues['Longitude'], ad_venues['VenueName']):
    label = '{}, {}'.format(lat, lng)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_local)  
    
map_local
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_7fba913a111c4672be5399b11cc42198%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7fba913a111c4672be5399b11cc42198%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7fba913a111c4672be5399b11cc42198%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_7fba913a111c4672be5399b11cc42198%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B33.951113%2C-84.142667%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2014%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# #### The next step is clustering the restaurant venues. After clustering, we can determine the centers of areas with the most restaurants.

# %%
# set number of clusters. I'm using K=6 to find smaller, more dense clusters
kclusters = 6

venue_clustering = ad_venues.drop('VenueName', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(venue_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([4, 1, 0, 4, 4, 0, 0, 0, 3, 0, 0, 1, 3, 1, 1, 1, 1, 0, 0, 0, 2, 0,
#        1, 0, 0, 1, 3, 3, 1, 1, 0, 3, 3, 3, 3, 3, 4, 1, 1, 0, 3, 0, 1, 4,
#        2, 3, 1, 3, 2, 0, 1, 0, 3, 3, 0, 3, 0, 4, 4, 4, 2, 2, 4, 0, 3, 5,
#        5, 4, 0, 1, 1, 3, 1, 2, 1, 1, 5, 1, 1, 3, 0, 5, 3, 1, 0, 1, 3, 0,
#        0, 0, 1, 3, 2, 0, 0, 0], dtype=int32)

# %%
# add clustering labels

#create NumPy array for 'clusters'
clusters = np.array(kmeans.labels_)
clusters

#add 'clusters' array as new column in ad_venues DataFrame
ad_venues['Clusters'] = clusters.tolist()
ad_venues.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            VenueName   Latitude  Longitude  Clusters
# 0  Costco Food Court  33.947416 -84.142963         4
# 1       Jang Su Jang  33.957040 -84.138763         1
# 2       Haru Ichiban  33.956893 -84.136399         0
# 3     Paris Baguette  33.952950 -84.140999         4
# 4          678 (육칠팔)  33.953473 -84.142153         4

# %%
# Let's get a visualization of the clusters with Folium

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=14)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, ven, cluster in zip(ad_venues['Latitude'], ad_venues['Longitude'], ad_venues['VenueName'], ad_venues['Clusters']):
    label = folium.Popup(str(ven) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)

       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_12c5a3fc60f64cfe8ec3450a9227b679%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_12c5a3fc60f64cfe8ec3450a9227b679%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_12c5a3fc60f64cfe8ec3450a9227b679%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_12c5a3fc60f64cfe8ec3450a9227b679%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B33.951113%2C-84.142667%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2014%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# #### Since the client's Dessert Shop lies within the Lime Green Cluster, shown above, we can recommend placing the Advertisement Boards centrally to the three largest adjacent clusters: Namely, those shown in Purple, Red and Aqua in the Folium map above.  We can use the centroids of those clusters as a reference points to recommend locations for the Advertisement Boards.

# %%
# Let's take a look at the distribution and size of our clusters
ad_venues.groupby('Clusters').count()
# Out:
#           VenueName  Latitude  Longitude
# Clusters
# 0                29        29         29
# 1                25        25         25
# 2                 7         7          7
# 3                21        21         21
# 4                10        10         10
# 5                 4         4          4

# %%
# Let's add cluster centroids to the map, with labels
# First, get coordinates of the centroids from clustering results

ad_venues.groupby('Clusters').mean()
# Out:
#            Latitude  Longitude
# Clusters
# 0         33.959447 -84.134741
# 1         33.960172 -84.141112
# 2         33.948976 -84.129431
# 3         33.955902 -84.131912
# 4         33.951253 -84.141207
# 5         33.952928 -84.149090

# %%
# Just adding a column to pass Cluster Numbers as pop-up labels on the Folium map
centers = ad_venues.groupby('Clusters').mean()
centers['Cluster_Num'] = ['0','1','2','3','4','5']
centers
# Out:
#            Latitude  Longitude Cluster_Num
# Clusters
# 0         33.959447 -84.134741           0
# 1         33.960172 -84.141112           1
# 2         33.948976 -84.129431           2
# 3         33.955902 -84.131912           3
# 4         33.951253 -84.141207           4
# 5         33.952928 -84.149090           5

# %%
#Now, add centroid markers to the map, with pop-up labels

for lat, lng, ctr in zip(centers['Latitude'], centers['Longitude'],centers['Cluster_Num']):
    label = folium.Popup(str(ctr), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='black',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7).add_to(map_clusters)
    
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_12c5a3fc60f64cfe8ec3450a9227b679%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_12c5a3fc60f64cfe8ec3450a9227b679%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_12c5a3fc60f64cfe8ec3450a9227b679%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_12c5a3fc60f64cfe8ec3450a9227b679%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B33.951113%2C-84.142667%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2014%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# #### Clusters 0, 1 and 3 are the dominant groups.  As we can see, those areas represent 75 out of 96 restaurant venues in the local area.  The client's Dessert Shop is also located in a cluster area that has 10 restaurants. Therefor, after placing their Ad Boards in the (3) recommended locations, they will have exposure to 88.5% (85/96) of restaurant customer foot traffic in their local area.  This should be a satisfactory outcome for the client.
